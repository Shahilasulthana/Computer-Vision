# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahilasulthana/Computer-Vision/blob/main/Best_visual_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load image in grayscale
img = cv2.imread('low_contrast.jpg', cv2.IMREAD_GRAYSCALE)

# Check if image is loaded
if img is None:
    raise ValueError("Image not found or path is incorrect")

# %%
linear_stretch = cv2.normalize(img, None, alpha=0, beta=255,
                               norm_type=cv2.NORM_MINMAX)

# %%
hist_eq = cv2.equalizeHist(img)

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
clahe_img = clahe.apply(img)

# %%
titles = ['Original Image',
          'Linear Contrast Stretching',
          'Histogram Equalization',
          'CLAHE']

images = [img, linear_stretch, hist_eq, clahe_img]

plt.figure(figsize=(10, 8))

for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.hist(images[i].ravel(), bins=256, range=(0,256))
    plt.title(titles[i])
    plt.xlabel('Pixel Intensity')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
